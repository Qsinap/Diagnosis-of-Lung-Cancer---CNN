# %% [markdown]
# ### Preliminaries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
import math
import matplotlib.pyplot as plt
from scipy.ndimage import zoom, rotate
from keras.utils import Sequence
from keras.models import Model
from keras.layers import Dense, Dropout, BatchNormalization, GlobalAveragePooling3D, Activation, Flatten
from keras.layers import MaxPool3D, Conv3D, Input, concatenate, Conv2D, MaxPool2D, GlobalAveragePooling2D
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.decomposition import PCA
import tensorflow as tf
import scipy.io as sio
import glob
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df = pd.read_csv("/content/drive/MyDrive/LIDC/final_data.csv")

# %%
agg_func = {'calcification': 'mean', 'internalStructure': 'mean', 'lobulation': 'mean', 'malignancy': 'mean',
            'margin': 'mean', 'path': 'first', 'sphericity': 'mean', 'spiculation': 'mean', 'subtlety': 'mean', 'texture': 'mean',
            'xf': 'first', 'xi': 'first', 'yf': 'first', 'yi': 'first', 'zf': 'first', 'zi': 'first'}

# %%
df = df.groupby("final_id").agg(agg_func)
df[['calcification', 'internalStructure', 'lobulation', 'malignancy', 'margin', 'sphericity', 'spiculation', 'subtlety', 'texture']] = df[['calcification', 'internalStructure', 'lobulation', 'malignancy', 'margin', 'sphericity', 'spiculation', 'subtlety', 'texture']]/df[['calcification', 'internalStructure', 'lobulation', 'malignancy', 'margin', 'sphericity', 'spiculation', 'subtlety', 'texture']].max()
df = df[['path', 'calcification', 'internalStructure', 'lobulation', 'malignancy',
       'margin', 'sphericity', 'spiculation', 'subtlety', 'texture']]

# %%
X_train, X_test, y_train, y_test = train_test_split(df.index.tolist(), df, stratify=df.malignancy, test_size=0.2, random_state=22)
ids_train = X_train
ids_test = X_test

# %%
tags_train = (df.loc[ids_train].malignancy.values > 0.5).astype(np.int)

# %%
class_weights = class_weight.compute_class_weight('balanced', np.unique(tags_train), tags_train)

# %%
n_classes = 2
chanels = 1
batch_size = 70
vol_size = np.array([42, 42, 42])

path_base = '/content/drive/MyDrive/LIDC/nodules-aug/{}.npz'

# %% [markdown]
# ### Functions

# %%
def normalize(npzarray):
    maxHU = 400.
    minHU = -1000.
    npzarray = (npzarray - minHU) / (maxHU - minHU)
    npzarray = np.clip(npzarray, 0, 1)
    return npzarray

# %%
def get_data(nodule_id, pos):
    tag = int(df.loc[nodule_id].malignancy > 0.5)
    
    file = np.load(path_base.format(str(nodule_id)+'-'+str(pos)))
    vol = file['patch']
    file.close()
    
    size_vol=np.shape(vol)
    vol = normalize(vol)
    vol = zoom(vol, vol_size/np.array(vol.shape), order=0)
    return vol, tag, size_vol

# %%
#maximum intensity projection
def MIP_data(nodule_id):
  tag = int(df.loc[nodule_id].malignancy > 0.5)
  file = np.load(path_base.format(nodule_id))
  vol = file['patch']
  file.close()

  size_vol=np.shape(vol)
  vol = normalize(vol)
  vol = zoom(vol, vol_size/np.array(vol.shape), order=0)
  vol = np.sum(vol, axis=0)/size_vol[0]

  return vol, tag, size_vol

# %%
def PCA_data(nodule_id):
  tag = int(df.loc[nodule_id].malignancy > 0.5)
  file = np.load(path_base.format(nodule_id))
  vol = file['patch']
  file.close()

  size_vol=np.shape(vol)
  vol = normalize(vol)
  vol = zoom(vol, vol_size/np.array(vol.shape), order=0)
  
  brain_pca = PCA(n_components=3)
  pca=[]
  for zi in range(vol_size[2]):
    pca.append(vol[:,:,zi].flatten())
  brain_pca.fit(pca)
  pca=np.transpose(brain_pca.components_).reshape(vol_size[0],vol_size[1],3)
  for ch in range(3):
    pca[...,ch]=(pca[...,ch]-np.min(pca[...,ch]))/(np.max(pca[...,ch])-np.min(pca[...,ch]))

  return pca, tag, size_vol

# %%
def slices_data(nodule_id):
  tag = int(df.loc[nodule_id].malignancy > 0.5)
  file = np.load(path_base.format(nodule_id))
  vol = file['patch']
  file.close()

  size_vol=np.shape(vol)
  vol = normalize(vol)
  ima=vol[int(size_vol[0]/2)-1:int(size_vol[0]/2)+2]
  ima=tf.image.resize(np.transpose(ima),(vol_size[1], vol_size[2]))

  return ima, tag, size_vol

# %%
degrees = [0, 90, -90, 80, -80, 70, -70]
axis = [0, 1, 2]

def get_random_params():
    d = np.random.choice(degrees)
    a = np.random.choice(axis, size=2, replace=False)
    return d, a

# %%
def plot_vol(vol):
  sv=np.shape(vol)
  ind=np.random.choice(sv[0])
  rows=round(np.sqrt(sv[3]))
  cols=math.ceil(sv[3]/rows)

  plt.figure(figsize=(10,10))
  for j in range(sv[3]):
    plt.subplot(rows,cols,j+1)
    plt.imshow(vol[ind,:,:,j,0])
    plt.title('slice '+str(j))
    plt.axis('off')

# %%
def getitem2(data, batch_size, is_training, idx=0, mode='vol'):

    batch_x = data[idx * batch_size:(idx + 1) * batch_size]
    
    X = []
    y = []
    vol=[]
    
    # se cargan los volumenes y las mascaras en sus respectivos arrays
    for path in batch_x:
        if mode=='vol':
          data, tag, sivol = get_data(path,1)
        if mode=='MIP':
          data, tag, sivol = MIP_data(path)
        if mode=='PCA':
          data, tag, sivol = PCA_data(path)
        if mode=='Slices':
          data, tag, sivol = slices_data(path)
        d, a = get_random_params()
        if is_training:
            data = rotate(data, d, a, reshape=False)
        X.append(data)
        vol.append(sivol)
        
        temp_y = [0, 0]
        temp_y[tag] = 1
        
        y.append(temp_y)
        
    X = np.array(X)
    y = np.array(y)
    vol=np.array(vol)
    
    try:
        X = X.reshape((*X.shape, chanels))
    except Exception as ex:
        print('ojooooooo')
        print(batch_x, ex)
    if mode=='PCA':
      X=X[...,0]
    if mode=='Slices':
      X=X[...,0]
    return X, vol, y

# %%
axix=[(0, 1), (0, 2), (1, 2)]
angle=[0, 90, 180, 270]
flip_ax={"(0, 1)":2,"(0, 2)":1, "(1, 2)":0}
flip_2=[1, 2, 0]

# %%
class Sequence_data(Sequence):

    def __init__(self, data, batch_size, is_training):
        # recive una lista de rutas de donde están los volumenes como numpy arrays y el batch_size
        self.data = data
        self.batch_size = batch_size
        self.is_training = is_training

    def __len__(self):
        return int(np.ceil(len(self.data) / float(self.batch_size)))

    def __getitem__(self, idx):
        # lista de rutas para el batch actual
        batch_x = self.data[idx * self.batch_size:(idx + 1) * self.batch_size]
        
        X = []
        y = []
        vol=[]
        
        # se cargan los volumenes y las mascaras en sus respectivos arrays
        for path in batch_x:
          for j in range(1,25):
            data, tag, vxl = get_data(path,j)

            X.append(data)            
            temp_y = [0, 0]
            temp_y[tag] = 1
            
            y.append(temp_y)
            vol.append(vxl)
            
        X = np.array(X)
        y = np.array(y)
        vol=np.array(vol)
        x0=X
        
        try:
            x0 = X.reshape((*X.shape, chanels))
        except Exception as ex:
            print('ojooooooo')
            print(batch_x, ex)
        return [x0, vol], y

# %%
'''xx=glob.glob('/content/drive/MyDrive/LIDC/nodules-aug/*.npz')
cont=0

for jj in xx:
  file = np.load(jj)
  file.close()
  print('\rProcess ', round(cont*100/64464,4), '%...' , end ="")
  cont=cont+1'''
# Out:
# 'xx=glob.glob(\'/content/drive/MyDrive/LIDC/nodules-aug/*.npz\')\ncont=0\n\nfor jj in xx:\n  file = np.load(jj)\n  file.close()\n  print(\'\rProcess \', round(cont*100/64464,4), \'%...\' , end ="")\n  cont=cont+1'

# %% [markdown]
# ### multipath and multimodal
# 3D network with input of the nodule dimensions.

# %%
def get_model_MLB(size = (128, 128, 64)):
    
    width, height, depth = size
    inputs = Input((width, height, depth, 1))

    #Layer 1
    l1 = Conv3D(filters=64, kernel_size=3, activation="relu")(inputs)
    l1 = BatchNormalization()(l1)

    l1 = Conv3D(filters=64, kernel_size=3, activation="relu")(l1)
    l1 = BatchNormalization()(l1)

    l1 = Conv3D(filters=128, kernel_size=3, activation="relu")(l1)
    l1 = BatchNormalization()(l1)

    l1 = Conv3D(filters=256, kernel_size=3, activation="relu")(l1)
    l1 = BatchNormalization()(l1)

    l1 = GlobalAveragePooling3D()(l1)
    l1 = Dense(units=150, activation="relu")(l1)
    l1 = Dropout(0.4)(l1)

    #Layer 2
    l2 = Conv3D(filters=64, kernel_size=5, activation="relu")(inputs)
    l2 = BatchNormalization()(l2)

    l2 = Conv3D(filters=64, kernel_size=5, activation="relu")(l2)
    l2 = BatchNormalization()(l2)

    l2 = Conv3D(filters=128, kernel_size=5, activation="relu")(l2)
    l2 = BatchNormalization()(l2)

    l2 = Conv3D(filters=256, kernel_size=5, activation="relu")(l2)
    l2 = BatchNormalization()(l2)

    l2 = GlobalAveragePooling3D()(l2)
    l2 = Dense(units=150, activation="relu")(l2)
    l2 = Dropout(0.3)(l2)

    #Layer 3
    l3 = Conv3D(filters=64, kernel_size=7, activation="relu")(inputs)
    l3 = BatchNormalization()(l3)

    l3 = Conv3D(filters=64, kernel_size=7, activation="relu")(l3)
    l3 = BatchNormalization()(l3)

    l3 = Conv3D(filters=128, kernel_size=7, activation="relu")(l3)
    l3 = BatchNormalization()(l3)

    l3 = Conv3D(filters=256, kernel_size=7, activation="relu")(l3)
    l3 = BatchNormalization()(l3)

    l3 = GlobalAveragePooling3D()(l3)
    l3 = Dense(units=150, activation="relu")(l3)
    l3 = Dropout(0.3)(l3)

    inp2 = Input((3)) #cantidad de datos extras
    
    con = concatenate([l1, l2, l3, inp2])
    
    x = Dense(units=50, activation="relu")(con)
    x = Dropout(0.3)(x)  

    outputs = Dense(units=2, activation="sigmoid")(x)

    # Define the model.
    model = Model(inputs=[inputs, inp2], outputs=[outputs], name="3dcnn")
    return model

# %%
def get_model_2D(size = (42, 42)):
    
    width, height = size

    inputs = Input((width, height, 3))

    x = Conv2D(filters=64, kernel_size=3, activation="relu")(inputs)
    x = MaxPool2D(pool_size=2)(x)
    x = BatchNormalization()(x)
    
    x = Conv2D(filters=128, kernel_size=3, activation="relu")(x)
    x = MaxPool2D(pool_size=2)(x)
    x = BatchNormalization()(x)
    
    x = Conv2D(filters=256, kernel_size=3, activation="relu")(x)
    x = MaxPool2D(pool_size=2)(x)
    x = BatchNormalization()(x)
    
    x = GlobalAveragePooling2D()(x)
    x = Dense(units=200, activation="relu")(x)
    x = Dropout(0.3)(x)

    #inp2 = Input((3)) #cantidad de datos extras
    #x = concatenate([x, inp2])

    x = Dense(units=100, activation="relu")(x)
    x = Dropout(0.3)(x)
    x = Dense(units=50, activation="relu")(x)
    x = Dropout(0.3)(x)   

    outputs = Dense(units=2, activation="sigmoid")(x)

    # Define the model.
    model = Model(inputs=inputs, outputs=outputs, name="2dmip")
    #model = Model(inputs=[inputs, inp2], outputs=[outputs], name="3dcnn")
    return model

# %%
def get_model_3D_multimodal(size = (128, 128, 64)):
    
    width, height, depth = size

    inputs = Input((width, height, depth, 1))

    x = Conv3D(filters=64, kernel_size=3, activation="relu")(inputs)
    x = MaxPool3D(pool_size=2)(x)
    x = BatchNormalization()(x)
    
    x = Conv3D(filters=128, kernel_size=3, activation="relu")(x)
    x = MaxPool3D(pool_size=2)(x)
    x = BatchNormalization()(x)
    
    x = Conv3D(filters=256, kernel_size=3, activation="relu")(x)
    x = MaxPool3D(pool_size=2)(x)
    x = BatchNormalization()(x)
    
    x = GlobalAveragePooling3D()(x)
    x = Dense(units=200, activation="relu")(x)
    x = Dropout(0.3)(x)

    inp2 = Input((3)) #cantidad de datos extras
    con = concatenate([x, inp2])

    x = Dense(units=100, activation="relu")(con)
    x = Dropout(0.3)(x)
    x = Dense(units=50, activation="relu")(x)
    x = Dropout(0.3)(x)   

    outputs = Dense(units=2, activation="sigmoid")(x)

    # Define the model.
    model = Model(inputs=[inputs, inp2], outputs=[outputs], name="3dcnn")
    return model

# %% [markdown]
# ### Data

# %%
ids=np.sort(np.concatenate((X_train,X_test)))
sis=np.shape(ids)[0]
volumes=[]

for nu, id in enumerate(ids):
  _,_,siz=get_data(id, 1)
  volumes.append(siz)
  print('\rProcess ', round(nu*100/sis,4), '%...' , end ="")
volumes=np.array(volumes)
# Out:
# Process  99.9628 %...

# %%
vol_m=volumes[...,0]*volumes[...,1]*volumes[...,2]
ids_v=np.argsort(vol_m)

# %% [markdown]
# ### Model

# %%
path_s='/content/drive/MyDrive/Indigo/weights_cancerPruebaAug'

# %%
if os.path.exists(path_s):
  print('done')
else:
  os.system('mkdir '+path_s)

# %%
model = get_model_3D_multimodal((42,42,42))
model.save(path_s+'/cancer_model.hdf5')
model.summary()
# Out:
# Model: "3dcnn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 42, 42, 42,  0
# __________________________________________________________________________________________________
# conv3d (Conv3D)                 (None, 40, 40, 40, 6 1792        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling3d (MaxPooling3D)    (None, 20, 20, 20, 6 0           conv3d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 20, 20, 20, 6 256         max_pooling3d[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 18, 18, 18, 1 221312      batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 9, 9, 9, 128) 0           conv3d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 9, 9, 9, 128) 512         max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 7, 7, 7, 256) 884992      batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 3, 3, 3, 256) 0           conv3d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 3, 3, 3, 256) 1024        max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling3d (Globa (None, 256)          0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 200)          51400       global_average_pooling3d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 200)          0           dense[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 3)]          0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 203)          0           dropout[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 100)          20400       concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 100)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 50)           5050        dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 50)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            102         dropout_2[0][0]
# ==================================================================================================
# Total params: 1,186,840
# Trainable params: 1,185,944
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='Adadelta', metrics=['accuracy'])

# %%
weight = {i : class_weights[i] for i in range(2)}

# %%
split=4
ind_s=int(np.shape(ids)[0]/split)

# %%
def indices(n_split):
  data_s=ids[ids_v][ind_s*n_split:ind_s*(n_split+1)]
  ram=np.random.choice(ind_s, ind_s, replace=False)
  data_s = data_s[ram]

  trai = data_s[:int(ind_s*0.7)]
  vali = data_s[int(ind_s*0.7):int(ind_s*0.8)]
  test = data_s[int(ind_s*0.8):]
  return trai, vali, test

# %%
batch_size=3
name_n="/Aug_3D_multimodal_split_"
for j in range(split):
    
  ids_train, ids_val, ids_test=indices(j)

  seq_train = Sequence_data(ids_train, batch_size, True)
  seq_valid = Sequence_data(ids_val, batch_size, False)

  ES = EarlyStopping(patience=20, min_delta=0.00001, restore_best_weights=True)
  MCP = ModelCheckpoint(filepath=path_s+name_n+str(j)+"_.{epoch:02d}.hdf5", save_best_only=False, save_weights_only=True)
  callbacks = [ES, MCP]

  results = model.fit(seq_train, validation_data=(seq_valid),  class_weight=weight , steps_per_epoch=int(len(ids_train)/batch_size), epochs=200, callbacks=callbacks)
  sio.savemat(path_s+name_n+str(j)+'_r.mat', results.history)
# Out:
# Epoch 1/200
# 156/156 [==============================] - 2930s 19s/step - loss: 0.9884 - accuracy: 0.4611 - val_loss: 0.8229 - val_accuracy: 0.3731
# Epoch 2/200
# 156/156 [==============================] - 45s 286ms/step - loss: 0.9164 - accuracy: 0.5029 - val_loss: 0.8171 - val_accuracy: 0.3731
# Epoch 3/200
# 156/156 [==============================] - 45s 286ms/step - loss: 0.8774 - accuracy: 0.5198 - val_loss: 0.7621 - val_accuracy: 0.4366
# Epoch 4/200
# 156/156 [==============================] - 45s 284ms/step - loss: 0.8564 - accuracy: 0.5243 - val_loss: 0.6785 - val_accuracy: 0.5721
# Epoch 5/200
# 156/156 [==============================] - 44s 283ms/step - loss: 0.8393 - accuracy: 0.5316 - val_loss: 0.6352 - val_accuracy: 0.5752
# Epoch 6/200
# 156/156 [==============================] - 45s 289ms/step - loss: 0.8266 - accuracy: 0.5419 - val_loss: 0.6229 - val_accuracy: 0.5933
# Epoch 7/200
# 156/156 [==============================] - 44s 282ms/step - loss: 0.8107 - accuracy: 0.5570 - val_loss: 0.6181 - val_accuracy: 0.6007
# Epoch 8/200
# 156/156 [==============================] - 44s 279ms/step - loss: 0.8108 - accuracy: 0.5508 - val_loss: 0.6166 - val_accuracy: 0.6150
# Epoch 9/200
# 156/156 [==============================] - 44s 279ms/step - loss: 0.8017 - accuracy: 0.5552 - val_loss: 0.6160 - val_accuracy: 0.6219
# Epoch 10/200
# 156/156 [==============================] - 44s 278ms/step - loss: 0.7965 - accuracy: 0.5554 - val_loss: 0.6152 - val_accuracy: 0.6269
# Epoch 11/200
# 156/156 [==============================] - 43s 274ms/step - loss: 0.7881 - accuracy: 0.5582 - val_loss: 0.6146 - val_accuracy: 0.6337
# Epoch 12/200
# 156/156 [==============================] - 42s 271ms/step - loss: 0.7817 - accuracy: 0.5638 - val_loss: 0.6152 - val_accuracy: 0.6231
# Epoch 13/200
# 156/156 [==============================] - 44s 279ms/step - loss: 0.
200
# 156/156 [==============================] - 45s 286ms/step - loss: 0.7136 - accuracy: 0.6151 - val_loss: 0.6056 - val_accuracy: 0.6940
# Epoch 48/200
# 156/156 [==============================] - 46s 295ms/step - loss: 0.7082 - accuracy: 0.6220 - val_loss: 0.6064 - val_accuracy: 0.6940
# Epoch 49/200
# 156/156 [==============================] - 45s 290ms/step - loss: 0.7016 - accuracy: 0.6256 - val_loss: 0.6066 - val_accuracy: 0.6835
# Epoch 50/200
# 156/156 [==============================] - 45s 288ms/step - loss: 0.7039 - accuracy: 0.6233 - val_loss: 0.6072 - val_accuracy: 0.6928
# Epoch 51/200
# 156/156 [==============================] - 45s 288ms/step - loss: 0.6994 - accuracy: 0.6290 - val_loss: 0.6050 - val_accuracy: 0.6859
# Epoch 52/200
# 156/156 [==============================] - 45s 288ms/step - loss: 0.7081 - accuracy: 0.6238 - val_loss: 0.6050 - val_accuracy: 0.6959
# Epoch 53/200
# 156/156 [==============================] - 45s 288ms/step - loss: 0.7043 - accuracy: 0.6251 - val_loss: 0.6046 - val_accuracy: 0.6872
# Epoch 54/200
# 156/156 [==============================] - 46s 292ms/step - loss: 0.7018 - accuracy: 0.6348 - val_loss: 0.6064 - val_accuracy: 0.6922
# Epoch 55/200
# 156/156 [==============================] - 46s 296ms/step - loss: 0.6967 - accuracy: 0.6330 - val_loss: 0.6056 - val_accuracy: 0.6940
# Epoch 56/200
# 156/156 [==============================] - 46s 291ms/step - loss: 0.6920 - accuracy: 0.6353 - val_loss: 0.6025 - val_accuracy: 0.6859
# Epoch 57/200
# 156/156 [==============================] - 45s 289ms/step - loss: 0.6988 - accuracy: 0.6298 - val_loss: 0.6043 - val_accuracy: 0.6965
# Epoch 58/200
# 156/156 [==============================] - 45s 289ms/step - loss: 0.6957 - accuracy: 0.6299 - val_loss: 0.6069 - val_accuracy: 0.6928
# Epoch 59/200
# 156/156 [==============================] - 45s 289ms/step - loss: 0.6933 - accuracy: 0.6311 - val_loss: 0.6044 - val_accuracy: 0.6903
# Epoch 60/200
# 156/156 [==============================] - 45s 287ms/step - loss: 0.6973 - accuracy: 0.6282 - val_loss: 0.6042 - val_accuracy: 0.6965
# Epoch 61/200
# 156/156 [==============================] - 47s 299ms/step - loss: 0.6921 - accuracy: 0.6326 - val_loss: 0.6041 - val_accuracy: 0.6884
# Epoch 62/200
# 156/156 [==============================] - 46s 291ms/step - loss: 0.6857 - accuracy: 0.6405 - val_loss: 0.6057 - val_accuracy: 0.6897
# Epoch 63/200
# 156/156 [==============================] - 46s 293ms/step - loss: 0.6946 - accuracy: 0.6331 - val_loss: 0.6047 - val_accuracy: 0.6915
# Epoch 64/200
# 156/156 [==============================] - 45s 289ms/step - loss: 0.6887 - accuracy: 0.6347 - val_loss: 0.6041 - val_accuracy: 0.7027
# Epoch 65/200
# 156/156 [==============================] - 45s 289ms/step - loss: 0.6906 - accuracy: 0.6339 - val_loss: 0.6008 - val_accuracy: 0.6884
# Epoch 66/200
# 156/156 [==============================] - 45s 290ms/step - loss: 0.6898 - accuracy: 0.6370 - val_loss: 0.6025 - val_accuracy: 0.6909
# Epoch 67/200
# 156/156 [==============================] - 46s 293ms/step - loss: 0.6946 - accuracy: 0.6378 - val_loss: 0.6037 - val_accuracy: 0.7058
# Epoch 68/200
# 156/156 [==============================] - 47s 301ms/step - loss: 0.6894 - accuracy: 0.6387 - val_loss: 0.6028 - val_accuracy: 0.6915
# Epoch 69/200
# 156/156 [==============================] - 46s 292ms/step - loss: 0.6816 - accuracy: 0.6423 - val_loss: 0.6024 - val_accuracy: 0.6909
# Epoch 70/200
# 156/156 [==============================] - 45s 290ms/step - loss: 0.6882 - accuracy: 0.6381 - val_loss: 0.6052 - val_accuracy: 0.7027
# Epoch 71/200
# 156/156 [==============================] - 45s 290ms/step - loss: 0.6817 - accuracy: 0.6372 - val_loss: 0.6006 - val_accuracy: 0.6915
# Epoch 72/200
# 156/156 [==============================] - 45s 286ms/step - loss: 0.6814 - accuracy: 0.6367 - val_loss: 0.6013 - val_accuracy: 0.6915
# Epoch 73/200
# 156/156 [==============================] - 46s 293ms/step - loss: 0.6871 - accuracy: 0.6343 - val_loss: 0.6010 - val_accuracy: 0.6866
# Epoch 74/200
# 156/156 [==============================] - 45s 290ms/step - loss: 0.6857 - accuracy: 0.6362 - val_loss: 0.6017 - val_accuracy: 0.6928
# Epoch 75/200
# 156/156 [==============================] - 48s 304ms/step - loss: 0.6777 - accuracy: 0.6442 - val_loss: 0.5999 - val_accuracy: 0.6853
# Epoch 76/200
# 156/156 [==============================] - 46s 292ms/step - loss: 0.6723 - accuracy: 0.6468 - val_loss: 0.5996 - val_accuracy: 0.6884
# Epoch 77/200
# 156/156 [==============================] - 46s 291ms/step - loss: 0.
200
# 156/156 [==============================] - 45s 287ms/step - loss: 0.6999 - accuracy: 0.7251 - val_loss: 0.3594 - val_accuracy: 0.9198
# Epoch 5/200
# 156/156 [==============================] - 45s 289ms/step - loss: 0.7053 - accuracy: 0.7270 - val_loss: 0.3580 - val_accuracy: 0.9241
# Epoch 6/200
# 156/156 [==============================] - 46s 296ms/step - loss: 0.6802 - accuracy: 0.7348 - val_loss: 0.3369 - val_accuracy: 0.9434
# Epoch 7/200
# 156/156 [==============================] - 45s 289ms/step - loss: 0.6907 - accuracy: 0.7420 - val_loss: 0.3318 - val_accuracy: 0.9484
# Epoch 8/200
# 156/156 [==============================] - 45s 288ms/step - loss: 0.6780 - accuracy: 0.7521 - val_loss: 0.3211 - val_accuracy: 0.9471
# Epoch 9/200
# 156/156 [==============================] - 45s 287ms/step - loss: 0.6730 - accuracy: 0.7492 - val_loss: 0.3154 - val_accuracy: 0.9502
# Epoch 10/200
# 156/156 [==============================] - 46s 294ms/step - loss: 0.6642 - accuracy: 0.7545 - val_loss: 0.3171 - val_accuracy: 0.9484
# Epoch 11/200
# 156/156 [==============================] - 45s 290ms/step - loss: 0.6507 - accuracy: 0.7604 - val_loss: 0.3097 - val_accuracy: 0.9527
# Epoch 12/200
# 156/156 [==============================] - 46s 292ms/step - loss: 0.6618 - accuracy: 0.7650 - val_loss: 0.3046 - val_accuracy: 0.9565
# Epoch 13/200
# 156/156 [==============================] - 46s 291ms/step - loss: 0.6480 - accuracy: 0.7653 - val_loss: 0.3008 - val_accuracy: 0.9565
# Epoch 14/200
# 156/156 [==============================] - 45s 290ms/step - loss: 0.6448 - accuracy: 0.7623 - val_loss: 0.3025 - val_accuracy: 0.9540
# Epoch 15/200
# 156/156 [==============================] - 46s 291ms/step - loss: 0.6585 - accuracy: 0.7690 - val_loss: 0.2946 - val_accuracy: 0.9552
# Epoch 16/200
# 156/156 [==============================] - 45s 290ms/step - loss: 0.6284 - accuracy: 0.7746 - val_loss: 0.2934 - val_accuracy: 0.9552
# Epoch 17/200
# 156/156 [==============================] - 47s 297ms/step - loss: 0.6443 - accuracy: 0.7721 - val_loss: 0.2917 - val_accuracy: 0.9552
# Epoch 18/200
# 156/156 [==============================] - 45s 290ms/step - loss: 0.6363 - accuracy: 0.7720 - val_loss: 0.2888 - val_accuracy: 0.9552
# Epoch 19/200
# 156/156 [==============================] - 45s 290ms/step - loss: 0.6339 - accuracy: 0.7801 - val_loss: 0.2865 - val_accuracy: 0.9546
# Epoch 20/200
# 156/156 [==============================] - 46s 292ms/step - loss: 0.6266 - accuracy: 0.7800 - val_loss: 0.2853 - val_accuracy: 0.9565
# Epoch 21/200
# 156/156 [==============================] - 45s 290ms/step - loss: 0.6319 - accuracy: 0.7789 - val_loss: 0.2812 - val_accuracy: 0.9546
# Epoch 22/200
# 156/156 [==============================] - 45s 289ms/step - loss: 0.6262 - accuracy: 0.7808 - val_loss: 0.2812 - val_accuracy: 0.9558
# Epoch 23/200
# 156/156 [==============================] - 46s 293ms/step - loss: 0.6302 - accuracy: 0.7820 - val_loss: 0.2801 - val_accuracy: 0.9546
# Epoch 24/200
# 156/156 [==============================] - 46s 293ms/step - loss: 0.6319 - accuracy: 0.7806 - val_loss: 0.2787 - val_accuracy: 0.9540
# Epoch 25/200
# 156/156 [==============================] - 46s 291ms/step - loss: 0.6178 - accuracy: 0.7883 - val_loss: 0.2791 - val_accuracy: 0.9540
# Epoch 26/200
# 156/156 [==============================] - 46s 292ms/step - loss: 0.6297 - accuracy: 0.7844 - val_loss: 0.2762 - val_accuracy: 0.9534
# Epoch 27/200
# 156/156 [==============================] - 45s 290ms/step - loss: 0.6158 - accuracy: 0.7921 - val_loss: 0.2787 - val_accuracy: 0.9546
# Epoch 28/200
# 156/156 [==============================] - 45s 286ms/step - loss: 0.6131 - accuracy: 0.7937 - val_loss: 0.2726 - val_accuracy: 0.9552
# Epoch 29/200
# 156/156 [==============================] - 45s 289ms/step - loss: 0.6232 - accuracy: 0.7857 - val_loss: 0.2728 - val_accuracy: 0.9558
# Epoch 30/200
# 156/156 [==============================] - 46s 295ms/step - loss: 0.6009 - accuracy: 0.7961 - val_loss: 0.2720 - val_accuracy: 0.9565
# Epoch 31/200
# 156/156 [==============================] - 45s 288ms/step - loss: 0.6088 - accuracy: 0.7919 - val_loss: 0.2741 - val_accuracy: 0.9558
# Epoch 32/200
# 156/156 [==============================] - 46s 292ms/step - loss: 0.
200
# 156/156 [==============================] - 47s 301ms/step - loss: 0.5069 - accuracy: 0.8414 - val_loss: 0.2549 - val_accuracy: 0.9540
# Epoch 136/200
# 156/156 [==============================] - 49s 310ms/step - loss: 0.5180 - accuracy: 0.8376 - val_loss: 0.2501 - val_accuracy: 0.9571
# Epoch 137/200
# 156/156 [==============================] - 48s 307ms/step - loss: 0.5147 - accuracy: 0.8375 - val_loss: 0.2485 - val_accuracy: 0.9583
# Epoch 138/200
# 156/156 [==============================] - 48s 307ms/step - loss: 0.5123 - accuracy: 0.8385 - val_loss: 0.2445 - val_accuracy: 0.9614
# Epoch 139/200
# 156/156 [==============================] - 48s 307ms/step - loss: 0.5088 - accuracy: 0.8408 - val_loss: 0.2451 - val_accuracy: 0.9621
# Epoch 140/200
# 156/156 [==============================] - 48s 304ms/step - loss: 0.5068 - accuracy: 0.8428 - val_loss: 0.2484 - val_accuracy: 0.9583
# Epoch 141/200
# 156/156 [==============================] - 47s 301ms/step - loss: 0.5161 - accuracy: 0.8391 - val_loss: 0.2487 - val_accuracy: 0.9596
# Epoch 142/200
# 156/156 [==============================] - 47s 303ms/step - loss: 0.5080 - accuracy: 0.8410 - val_loss: 0.2497 - val_accuracy: 0.9596
# Epoch 143/200
# 156/156 [==============================] - 48s 311ms/step - loss: 0.5073 - accuracy: 0.8422 - val_loss: 0.2444 - val_accuracy: 0.9639
# Epoch 144/200
# 156/156 [==============================] - 48s 306ms/step - loss: 0.5069 - accuracy: 0.8403 - val_loss: 0.2453 - val_accuracy: 0.9621
# Epoch 145/200
# 156/156 [==============================] - 48s 305ms/step - loss: 0.5063 - accuracy: 0.8378 - val_loss: 0.2512 - val_accuracy: 0.9552
# Epoch 146/200
# 156/156 [==============================] - 48s 303ms/step - loss: 0.5134 - accuracy: 0.8367 - val_loss: 0.2451 - val_accuracy: 0.9614
# Epoch 147/200
# 156/156 [==============================] - 48s 304ms/step - loss: 0.4992 - accuracy: 0.8454 - val_loss: 0.2477 - val_accuracy: 0.9608

# %% [markdown]
# ### Graphics

# %%
def plot_t(his_m, mtc='accuracy', name='none'):
  plt.figure(figsize=(15,5))
  plt.subplot(1,2,1)
  plt.plot(his_m[mtc][0])
  plt.plot(his_m['val_'+mtc][0])
  plt.title(mtc)
  plt.ylabel(mtc)
  plt.ylim((0, 1))
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')

  plt.subplot(1,2,2)
  plt.plot(his_m['loss'][0])
  plt.plot(his_m['val_loss'][0])
  plt.title('model loss')
  plt.ylabel('value')
  plt.ylim((0, 1))
  plt.xlabel('epoch')
  plt.legend(['train', 'test'], loc='upper left')

  if not name=='none':
    plt.savefig(name)

# %%
histories=glob.glob(path_s+'/*.mat')

# %%
plot_t(sio.loadmat(histories[3]))

# %% [markdown]
# ### Test data

# %%
x1_test, x2_test, y_test=getitem2(ids_test, np.shape(ids_test)[0], False)

# %%
results = model.evaluate([x1_test, x2_test], y_test)

y_hat=model.predict([x1_test, x2_test])
# Out:
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3503 - accuracy: 0.8741

# %%
print(classification_report(np.argmax(y_test, axis=1), np.argmax(y_hat, axis=1), digits=5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.72727   0.36364   0.48485        22
#            1    0.88710   0.97345   0.92827       113
#
#     accuracy                        0.87407       135
#    macro avg    0.80718   0.66854   0.70656       135
# weighted avg    0.86105   0.87407   0.85601       135
